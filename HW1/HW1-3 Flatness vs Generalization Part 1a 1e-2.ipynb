# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from PIL import Image
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_data(train_size, test_size):
    train_loader = torch.utils.data.DataLoader(datasets.MNIST('data', train = True, download=True, transform=transforms.Compose([transforms.Resize((32, 32)), transforms.ToTensor()])), batch_size = train_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(datasets.MNIST('data', train = False, transform=transforms.Compose([transforms.Resize((32, 32)), transforms.ToTensor()])), batch_size = test_size, shuffle=True)
    return (train_loader, test_loader)

# %%
class Modeln(nn.Module):
    def __init__(self):
        super(Modeln, self).__init__()
        self.cn1 = nn.Conv2d(1, 6, 5)
        self.cn2 = nn.Conv2d(6, 16, 5)
        self.lin1 = nn.Linear(16 * 5 * 5, 120)
        self.lin2 = nn.Linear(120, 84)
        self.lin3 = nn.Linear(84, 10)
    def forward(self, x):
        a = F.max_pool2d(F.relu(self.cn1(a)), 2)
        a = F.max_pool2d(F.relu(self.cn2(a)), 2)
        a = x.view(x.size()[0], -1)
        a = F.relu(self.lin1(a))
        a = F.relu(self.lin2(a))
        a = self.lin3(a)
        return a

# %%
def calculate_parameters(modelName, model):
    param = sum(p.numel() for p in model.parameters())
    print('{}: {}'.format(modelName, param))
    return param

# %%
def init_optimizer(model):
    return optim.SGD(model.parameters(), lr=1e-2, momentum=0.9, nesterov=True)

# %%
def train(model, optimizer, train_loader):
    model.train()
    for batch_id, (data, target) in enumerate(train_loader):
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()
        output = model(data)
        loss = loss_funct(output, target)
        loss.backward()
        optimizer.step()

# %%
def calculate_loss(model, loader, loss_fn):
    correct = 0
    total = 0
    costTotal = 0
    costCounter = 0
    with torch.no_grad():
        for batch in loader:
            data, target = batch
            output = model(data)
            cost = loss_funct(output, target)
            costTotal += cost
            costCounter += 1
            for i, outputTensor in enumerate(output):
                if torch.argmax(outputTensor) == target[i]:
                    correct += 1
                total += 1
    return costTotal / costCounter, round(correct/total, 3)

# %%
def train_model(model, optimizer, train_data, test_data):
    print('Training model ')
    for epoch in range(1, epochs + 1):
        train(model, optimizer, train_data)
        loss_train, acc_train = calculate_loss(model, train_data, loss_funct)
        loss_test, acc_test = calculate_loss(model, test_data, loss_funct)
    train_loss_lst.append(loss_train)
    test_loss_lst.append(loss_test)
    train_acc_lst.append(acc_train)
    test_acc_lst.append(acc_test)
    print("test loss - ", loss_test, "epoch - ", epoch)

# %%
train_loss_lst = []
test_loss_lst = []
test_acc_lst= []
train_acc_lst = []
epochs = 28
train_data, test_data = load_data(64, 64)
model = Modeln()
loss_funct = torch.nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-2)
train_loss_lst_m1, test_loss_lst_m1, train_acc_lst_m1, test_acc_lst_m1 = train_model(model, optimizer, train_data, test_data)
# Out:
# Training model
# test loss -  tensor(0.0835)  epoch -  1
# test loss -  tensor(0.0558)  epoch -  2
# test loss -  tensor(0.0637)  epoch -  3
# test loss -  tensor(0.0422)  epoch -  4
# test loss -  tensor(0.0398)  epoch -  5
# test loss -  tensor(0.0334)  epoch -  6
# test loss -  tensor(0.0397)  epoch -  7
# test loss -  tensor(0.0408)  epoch -  8
# test loss -  tensor(0.0358)  epoch -  9
# test loss -  tensor(0.0321)  epoch -  10
# test loss -  tensor(0.0350)  epoch -  11
# test loss -  tensor(0.0349)  epoch -  12
# test loss -  tensor(0.0331)  epoch -  13
# test loss -  tensor(0.0439)  epoch -  14
# test loss -  tensor(0.0307)  epoch -  15
# test loss -  tensor(0.0428)  epoch -  16
# test loss -  tensor(0.0403)  epoch -  17
# test loss -  tensor(0.0491)  epoch -  18
# test loss -  tensor(0.0397)  epoch -  19
# test loss -  tensor(0.0328)  epoch -  20
# test loss -  tensor(0.0353)  epoch -  21
# test loss -  tensor(0.0437)  epoch -  22
# test loss -  tensor(0.0336)  epoch -  23
# test loss -  tensor(0.0455)  epoch -  24
# test loss -  tensor(0.0391)  epoch -  25
# test loss -  tensor(0.0352)  epoch -  26
# test loss -  tensor(0.0476)  epoch -  27
# test loss -  tensor(0.0357)  epoch -  28
# Training completed..

# %%
train_data, test_data = load_data(1024, 1024)
model = Modeln()
loss_funct = torch.nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-2)
train_loss_lst_m2, test_loss_lst_m2, train_acc_lst_m2, test_acc_lst_m2 = train_model(model, optimizer, train_data, test_data)
# Out:
# Training model
# test loss -  tensor(2.2834)  epoch -  1
# test loss -  tensor(1.2371)  epoch -  2
# test loss -  tensor(0.3386)  epoch -  3
# test loss -  tensor(0.2340)  epoch -  4
# test loss -  tensor(0.1738)  epoch -  5
# test loss -  tensor(0.1366)  epoch -  6
# test loss -  tensor(0.1135)  epoch -  7
# test loss -  tensor(0.1206)  epoch -  8
# test loss -  tensor(0.0884)  epoch -  9
# test loss -  tensor(0.0808)  epoch -  10
# test loss -  tensor(0.0772)  epoch -  11
# test loss -  tensor(0.0678)  epoch -  12
# test loss -  tensor(0.0712)  epoch -  13
# test loss -  tensor(0.0630)  epoch -  14
# test loss -  tensor(0.0592)  epoch -  15
# test loss -  tensor(0.0596)  epoch -  16
# test loss -  tensor(0.0559)  epoch -  17
# test loss -  tensor(0.0537)  epoch -  18
# test loss -  tensor(0.0514)  epoch -  19
# test loss -  tensor(0.0541)  epoch -  20
# test loss -  tensor(0.0486)  epoch -  21
# test loss -  tensor(0.0492)  epoch -  22
# test loss -  tensor(0.0484)  epoch -  23
# test loss -  tensor(0.0500)  epoch -  24
# test loss -  tensor(0.0439)  epoch -  25
# test loss -  tensor(0.0440)  epoch -  26
# test loss -  tensor(0.0509)  epoch -  27
# test loss -  tensor(0.0403)  epoch -  28
# Training completed..

# %%
thetha1 = torch.nn.utils.parameters_to_vector(model.parameters())
thetha2 = torch.nn.utils.parameters_to_vector(model2.parameters())

# %%
plt.figure(figsize=(12,6))
plt.plot(np.arange(0, 28, 1), train_loss_arr_m1, color = "orange")
plt.plot(np.arange(0, 28, 1), train_loss_arr_m2, color = "purple")
plt.title('Model Loss Comparision')
plt.legend(['Batch size = 64', 'Batch size = 1024'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(np.arange(0, 28, 1), test_accuracy_arr_m1, color = "orange")
plt.plot(np.arange(0, 28, 1), test_accuracy_arr_m2, color = "purple")
plt.title('Model Accuracy Comparision')
plt.legend(['Batch size = 64', 'Batch size = 1024'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %%
thetha_alpha = np.arange(-2, 2, 0.2)
theta_lst =[]
for i in range (len(thetha_alpha)):
    th = (1-thetha_alpha[i])*thetha1 + thetha_alpha[i]* thetha2
    theta_lst.append(th)

# %%
loss_train_alpha_lst = []
loss_test_alpha_lst = []
acc_train_alpha_lst = []
acc_test_alpha_lst = []
for i in range (len(theta_lst)):
    print('Running for theta - ' , i)
    th = (1-thetha_alpha[i])*thetha1 + thetha_alpha[i]* thetha2
    model = Modeln()
    torch.nn.utils.vector_to_parameters(th, model.parameters())
    loss_function = nn.CrossEntropyLoss()
    temp = []
    for p in model.parameters():
        temp.append(torch.numel(p))
    alpha_loss_train, alpha_acc_train = calculate_loss(model, train_data)
    alpha_loss_test, alpha_acc_test = calculate_loss(model, test_data)
    print('Alpha Loss - ' , alpha_loss_test)
    loss_train_alpha_lst.append(alpha_loss_train)
    acc_train_alpha_lst.append(alpha_acc_train)
    loss_test_alpha_lst.append(alpha_loss_test)
    acc_test_alpha_lst.append(alpha_acc_test)
# Out:
# Running for theta -  0
# Alpha loss -  tensor(23.8347)
# Running for theta -  1
# Alpha loss -  tensor(15.7203)
# Running for theta -  2
# Alpha loss -  tensor(10.1654)
# Running for theta -  3
# Alpha loss -  tensor(6.3898)
# Running for theta -  4
# Alpha loss -  tensor(3.8655)
# Running for theta -  5
# Alpha loss -  tensor(2.1941)
# Running for theta -  6
# Alpha loss -  tensor(1.1717)
# Running for theta -  7
# Alpha loss -  tensor(0.5629)
# Running for theta -  8
# Alpha loss -  tensor(0.2428)
# Running for theta -  9
# Alpha loss -  tensor(0.0963)
# Running for theta -  10
# Alpha loss -  tensor(0.0357)
# Running for theta -  11
# Alpha loss -  tensor(0.0328)
# Running for theta -  12
# Alpha loss -  tensor(0.7101)
# Running for theta -  13
# Alpha loss -  tensor(1.5067)
# Running for theta -  14
# Alpha loss -  tensor(0.2619)
# Running for theta -  15
# Alpha loss -  tensor(0.0403)
# Running for theta -  16
# Alpha loss -  tensor(0.1202)
# Running for theta -  17
# Alpha loss -  tensor(0.7076)
# Running for theta -  18
# Alpha loss -  tensor(3.7366)
# Running for theta -  19
# Alpha loss -  tensor(14.5919)

# %%
plt.figure(figsize=(12,6))
plt.plot(alpha, loss_train_alpha_lst, color = "orange")
plt.plot(alpha, loss_test_alpha_lst, color = "purple")
plt.xlabel('Interpolation ratio')
plt.ylabel('Loss')
plt.legend(['Training Loss' , 'Testing Loss'])

# %%
plt.plot(alpha, alpha_train_acc_arr, dashes=[30, 5, 10, 5], color = "orange")
plt.plot(alpha, alpha_test_acc_arr, color = "purple")
plt.legend(['Train Accuracy' , 'Test Accuracy'])
plt.xlabel('Interpolation ratio')
plt.ylabel('Accuracy')
